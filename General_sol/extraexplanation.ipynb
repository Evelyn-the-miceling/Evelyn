# %% [markdown]
# ### **1. Read `records.csv` and return the student's information as an analysable data structure:**
#
# We will read the file and convert each line (each student's information) into a dictionary*. The output will be a dictionary with the `key:value` pair as their tutorial group number and a list of all members with the dictionary that has the student's info inside that. We will do with 4 steps:
#
# **step 1 Read `records.csv`:** \
# open the file using Python’s built-in file I/O. The file contains student information in the following format: tutorial_group, student_id, school, name, gender, cgpa \
# We skip the header row and process each remaining line.
#
# **step 2 Convert each line into a dictionary:** \
# Each line represents one student. We split the line by , and convert it into a dictionary
#
# **step 3 Gather all student dictionaries into a single list:** \
# Every converted dictionary from Step 2 is appended into one big list called 'students'
#
# **step 4 Rearrange the list into a dictionary grouped by tutorial group:** \
# we create a new dictionary where the key is the tutorial group and the value is a list of all students belonging to that tutorial group.
#
# ###### *The reason why we contain every student's information as a dictionary, not a tuple is because it is easier to add in their allocated group's information with the existing student's information as a `key:value` pair.

# %% [markdown]
# ### **2. Analyse the `records.csv` file.:**
#
# We will analyze the data to understand the characteristics of each tutorial group. This is to identify potential imbalances in gender, CGPA, and school representation before doing any subgroup allocation. This step will generate 3 graphs. We will do with 4 steps:
#
# **step 1 Compute key statistics for each tutorial group:** \
# For every tutorial group, we calculate: Number of male students, Mean CGPA of the group, and Maximum number of students coming from the same school
#
# **step 2 Plot the number of male students in each tutorial group:** \
# We generate a bar graph showing the number of male students in each tutorial group.
#
# **step 3 Plot the mean CGPA of each tutorial group:** \
# We generate a bar graph showing the average CGPA for each tutorial group.
#
# **step 4 Plot the maximum number of students from the same school:** \
# We generate a bar graph showing the maximum number of students who come from the same school.
